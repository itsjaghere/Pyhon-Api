# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['owase',
#  'busselton',
#  'sola',
#  'carnarvon',
#  'illoqqortoormiut',
#  'puerto del rosario',
#  'arlit',
#  'bluff',
#  'luderitz',
#  'naze',
#  'hobart',
#  'chilliwack',
#  'leningradskiy',
#  'port blair',
#  'lorengau',
#  'barrow',
#  'odienne',
#  'jamestown',
#  'sciacca',
#  'rikitea',
#  'longyearbyen',
#  'smirnykh',
#  'puerto ayora',
#  'barentsburg',
#  'chickasha',
#  'nuuk',
#  'tayturka',
#  'georgetown',
#  'aykhal',
#  'punta arenas',
#  'vaini',
#  'umm lajj',
#  'baiyin',
#  'chakwal',
#  'wanning',
#  'broken hill',
#  'mayumba',
#  'aklavik',
#  'lebu',
#  'kampot',
#  'padang',
#  'cape town',
#  'saint-augustin',
#  'gushikawa',
#  'new norfolk',
#  'hilo',
#  'shipitsyno',
#  'tommot',
#  'sentyabrskiy',
#  'prince george',
#  'alice springs',
#  'saint george',
#  'kavieng',
#  'butaritari',
#  'arraial do cabo',
#  'souillac',
#  'lata',
#  'pevek',
#  'manta',
#  'kirkuk',
#  'taolanaro',
#  'upernavik',
#  'cayenne',
#  'guane',
#  'bredasdorp',
#  'eureka',
#  'garowe',
#  'sorland',
#  'ponta do sol',
#  'marawi',
#  'albany',
#  'mishelevka',
#  'linhares',
#  'mar del plata',
#  'tasiilaq',
#  'barra do bugres',
#  'fairbanks',
#  'avarua',
#  'moron',
#  'lagoa',
#  'chuy',
#  'high level',
#  'bolungarvik',
#  'sebinkarahisar',
#  'jacqueville',
#  'thompson',
#  'mataura',
#  'nikolskoye',
#  'vardo',
#  'faya',
#  'urucui',
#  'udachnyy',
#  'atuona',
#  'caxito',
#  'mocambique',
#  'sarahan',
#  'saint-philippe',
#  'terrace',
#  'vostok',
#  'port elizabeth',
#  'phanom thuan',
#  'ketchikan',
#  'novobirilyussy',
#  'hermanus',
#  'vanavara',
#  'yellowknife',
#  'salvador',
#  'mosquera',
#  'evensk',
#  'puerto baquerizo moreno',
#  'victoria',
#  'kirkwall',
#  'margate',
#  'kruisfontein',
#  'samarai',
#  'rognac',
#  'port alfred',
#  'talcahuano',
#  'castro',
#  'provideniya',
#  'cidreira',
#  'cachoeiras de macacu',
#  'damavand',
#  'freeport',
#  'sitka',
#  'faanui',
#  'hobyo',
#  'knyaze-volkonskoye',
#  'ribeira grande',
#  'port augusta',
#  'villarrica',
#  'ondjiva',
#  'fortuna',
#  'codrington',
#  'tiksi',
#  'pointe michel',
#  'praia da vitoria',
#  'minot',
#  'darnah',
#  'kapaa',
#  'najran',
#  'portland',
#  'mushie',
#  'qaanaaq',
#  'vaitupu',
#  'izazi',
#  'chivay',
#  'sholokhovskiy',
#  'moberly',
#  'nouadhibou',
#  'isangel',
#  'ryotsu',
#  'lamu',
#  'ushuaia',
#  'ampanihy',
#  'araouane',
#  'hay river',
#  'kaitangata',
#  'aketi',
#  'saskylakh',
#  'kazalinsk',
#  'belushya guba',
#  'khatanga',
#  'marcona',
#  'hernani',
#  'port-gentil',
#  'tumannyy',
#  'touros',
#  'salalah',
#  'bengkulu',
#  'dukat',
#  'sindor',
#  'ipanema',
#  'mokhsogollokh',
#  'oroszlany',
#  'lompoc',
#  'samusu',
#  'tuktoyaktuk',
#  'hasaki',
#  'machilipatnam',
#  'kuzhithurai',
#  'vila',
#  'krabi',
#  'kununurra',
#  'hithadhoo',
#  'komsomolskiy',
#  'cherskiy',
#  'sinnamary',
#  'ahipara',
#  'bambous virieux',
#  'fairview',
#  'caravelas',
#  'grand gaube',
#  'rauma',
#  'dikson',
#  'houston',
#  'severo-kurilsk',
#  'kerema',
#  'lavrentiya',
#  'pacifica',
#  'nizhneyansk',
#  'katherine',
#  'jumla',
#  'alyangula',
#  'namatanai',
#  'zhicheng',
#  'tchollire',
#  'pringsewu',
#  'banff',
#  'amderma',
#  'coihaique',
#  'diego de almagro',
#  'kailua',
#  'mendeleyevsk',
#  'akyab',
#  'mys shmidta',
#  'stornoway',
#  'moranbah',
#  'kondoa',
#  'krasnyy chikoy',
#  'pangnirtung',
#  'broome',
#  'tucurui',
#  'bambanglipuro',
#  'vangaindrano',
#  'hofn',
#  'dalvik',
#  'norman wells',
#  'caluquembe',
#  'puerto madero',
#  'chapais',
#  'sabang',
#  'bathsheba',
#  'rudbar',
#  'bilma',
#  'sarajevo',
#  'warqla',
#  'sur',
#  'aksu',
#  'nan',
#  'zambezi',
#  'fort wellington',
#  'kaduqli',
#  'juneau',
#  'knittelfeld',
#  'north platte',
#  'teno',
#  'san lawrenz',
#  'diamantino',
#  'fort nelson',
#  'soavinandriana',
#  'kavaratti',
#  'emba',
#  'erzin',
#  'cabo san lucas',
#  'zolotinka',
#  'eyl',
#  'la ronge',
#  'hauterive',
#  'krasnoselkup',
#  'clyde river',
#  'mehamn',
#  'east london',
#  'isabela',
#  'mitu',
#  'vestmannaeyjar',
#  'riohacha',
#  'rungata',
#  'magadan',
#  'tucupita',
#  'vao',
#  'mansa',
#  'manica',
#  'cortez',
#  'smithers',
#  'baykit',
#  'khaniotis',
#  'ajdabiya',
#  'key largo',
#  'ust-koksa',
#  'coahuayana',
#  'sulurpeta',
#  'airai',
#  'attawapiskat',
#  'port hardy',
#  'zyryanka',
#  'baruun-urt',
#  'celestun',
#  'hamilton',
#  'valparaiso',
#  'khani',
#  'oshnaviyeh',
#  'saint-paul',
#  'chegdomyn',
#  'boddam',
#  'geraldton',
#  'poum',
#  'sassandra',
#  'grahamstown',
#  'cururupu',
#  'meyungs',
#  'paragominas',
#  'teknaf',
#  'port macquarie',
#  'nyurba',
#  'srednekolymsk',
#  'yichun',
#  'tanete',
#  'shimoda',
#  'vestmanna',
#  'podor',
#  'joshimath',
#  'asau',
#  'bundaberg',
#  'sept-iles',
#  'nampula',
#  'barcelos',
#  'bulgan',
#  'springbok',
#  'sao filipe',
#  'rocha',
#  'hurghada',
#  'hambantota',
#  'narsaq',
#  'husavik',
#  'mahebourg',
#  'demba',
#  'tura',
#  'san patricio',
#  'madimba',
#  'shingu',
#  'lima',
#  'bahar',
#  'oyama',
#  'ilulissat',
#  'berbera',
#  'nipawin',
#  'katsuura',
#  'wuda',
#  'vinh',
#  'ridge',
#  'apango',
#  'lensk',
#  'bethel',
#  'jieshi',
#  'ancud',
#  'qasigiannguit',
#  'mujiayingzi',
#  'esperance',
#  'tezu',
#  'taoudenni',
#  'christchurch',
#  'chumikan',
#  'abadan',
#  'vossevangen',
#  'chokurdakh',
#  'vysokogornyy',
#  'yumen',
#  'dunedin',
#  'pucallpa',
#  'zhitikara',
#  'flinders',
#  'mwene-ditu',
#  'bosaso',
#  'nisia floresta',
#  'tuatapere',
#  'pangai',
#  'makushino',
#  'kadykchan',
#  'pampa',
#  'acarau',
#  'raudeberg',
#  'marshall',
#  'teguise',
#  'constitucion',
#  'sisimiut',
#  'hendijan',
#  'sotnikovo',
#  'takab',
#  'maniitsoq',
#  'naryan-mar',
#  'pitimbu',
#  'mentok',
#  'kapuskasing',
#  'paamiut',
#  'saint anthony',
#  'qianan',
#  'katsina',
#  'kahului',
#  'hibbing',
#  'porto novo',
#  'torbay',
#  'cerritos',
#  'ponta delgada',
#  'pazardzik',
#  'velikie luki',
#  'vila franca do campo',
#  'muros',
#  'puerto cortes',
#  'ahuimanu',
#  'gardendale',
#  'douglas',
#  'osmena',
#  'laguna',
#  'tynda',
#  'pisco',
#  'kargasok',
#  'saldanha',
#  'karakol',
#  'pishin',
#  'mareeba',
#  'comodoro rivadavia',
#  'man',
#  'veselynove',
#  'jalu',
#  'vengerovo',
#  'brae',
#  'lazaro cardenas',
#  'cotonou',
#  'kodiak',
#  'shaartuz',
#  'kirakira',
#  'phan rang',
#  'iquique',
#  'horsham',
#  'pita',
#  'coquimbo',
#  'maningrida',
#  'tiznit',
#  'luba',
#  'cozumel',
#  'severnyy',
#  'chiang kham',
#  'port lincoln',
#  'khanpur',
#  'bitung',
#  'kassala',
#  'nanchang',
#  'podosinovets',
#  'muravlenko',
#  'mount gambier',
#  'dhemaji',
#  'shagonar',
#  'progreso',
#  'prieska',
#  'nanortalik',
#  'totness',
#  'murray',
#  'gopalpur',
#  'kannur',
#  'marabba',
#  'barsovo',
#  'cockburn town',
#  'berlevag',
#  'yulara',
#  'aranos',
#  'thaba-tseka',
#  'onega',
#  'kropotkin',
#  'alugan',
#  'bartica',
#  'loei',
#  'ganzhou',
#  'rafai',
#  'khartoum',
#  'fayetteville',
#  'diffa',
#  'seydi',
#  'hami',
#  'humaita',
#  'trinidad',
#  'nome',
#  'millbrook',
#  'grindavik',
#  'iqaluit',
#  'goure',
#  'sayyan',
#  'vitimskiy',
#  'mananara',
#  'batagay-alyta',
#  'pochutla',
#  'point fortin',
#  'artyk',
#  'shar',
#  'gat',
#  'luis correia',
#  'manali',
#  'plettenberg bay',
#  'buta',
#  'kozova',
#  'ardakan',
#  'cobija',
#  'keningau',
#  'hit',
#  'jejuri',
#  'shemonaikha',
#  'marystown',
#  'talnakh',
#  'nanhai',
#  'hirara',
#  'walvis bay',
#  'dingle',
#  'hatillo',
#  'umm kaddadah',
#  'sug-aksy',
#  'goderich',
#  'madurai',
#  'shonguy',
#  'mabaruma',
#  'falealupo',
#  'makakilo city',
#  'ndele',
#  'mahon',
#  'kaeo',
#  'hovd',
#  'merauke',
#  'tsihombe',
#  'trelew',
#  'ilabaya',
#  'sao jose da coroa grande',
#  'praya',
#  'watrous',
#  'marrakesh',
#  'santo domingo',
#  'nalut',
#  'peringat',
#  'namibe',
#  'inuvik',
#  'albacete',
#  'pointe-noire',
#  'leisure city',
#  'te anau',
#  'salamanca',
#  'inderborskiy',
#  'jiwani',
#  'belyy yar',
#  'pauini',
#  'omsukchan',
#  'susangerd',
#  'sakakah',
#  'belmonte',
#  'los llanos de aridane',
#  'scottsbluff',
#  'san rafael',
#  'baghdad',
#  'keflavik',
#  'zachagansk',
#  'datong',
#  'hoopstad',
#  'porto belo',
#  'formosa',
#  'grand river south east',
#  'somerset west',
#  'sao gabriel da cachoeira',
#  'porto nacional',
#  'charagua',
#  'kloulklubed',
#  'whitehorse',
#  'korablino',
#  'yarmouth',
#  'kieta',
#  'naklo nad notecia',
#  'kolondieba',
#  'catamarca',
#  'yeppoon',
#  'andenes',
#  'hashtrud',
#  'lanzhou',
#  'ouro preto do oeste',
#  'maxixe',
#  'wulanhaote',
#  'ayna',
#  'frontera',
#  'safwah',
#  'kalemie',
#  'olga',
#  'guerrero negro',
#  'fare',
#  'palu',
#  'ambilobe',
#  'provost',
#  'balgazyn',
#  'hihifo',
#  'kyshtovka',
#  'nelson bay',
#  'kamaishi',
#  'vilyuysk',
#  'umiray',
#  'namie',
#  'la rioja',
#  'birin',
#  'lexington park',
#  'sumabnit',
#  'worland',
#  'remontnoye',
#  'hirado',
#  'yakeshi',
#  'ruteng',
#  'inirida',
#  'plainview',
#  'toora-khem',
#  'irtyshskiy',
#  'helena',
#  'kawhia',
#  'ust-maya',
#  'zwedru',
#  'jiazi',
#  'prince rupert',
#  'dulce nombre de culmi',
#  'aflu',
#  'banmo',
#  'magway',
#  'saleaula',
#  'adrar',
#  'huazolotitlan',
#  'riviere-au-renard',
#  'chokwe',
#  'kolyvan',
#  'mae sot']

# %%
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid={api_key}&units={units}&q="
query_url
first_city = "owase"
test = requests.get(query_url + first_city).json()
print(json.dumps(test, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.07,
#         "lon": 136.2
#     },
#     "dt": 1559098590,
#     "id": 1853514,
#     "main": {
#         "humidity": 49,
#         "pressure": 1008,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Owase",
#     "sys": {
#         "country": "JP",
#         "id": 8014,
#         "message": 0.0052,
#         "sunrise": 1559072781,
#         "sunset": 1559123941,
#         "type": 1
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "gust": 12.3,
#         "speed": 16.11
#     }
# }

# %%
found_city = []
percent_cloud = []
country = []
date = []
percent_humidity = []
latitude = []
longitude = []
temp = []
wind_mph = []

for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        found_city.append(response["name"]) 
        percent_cloud.append(response["clouds"]["all"]) 
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        percent_humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"]) 
        longitude.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        wind_mph.append(response["wind"]["speed"])
        
    except KeyError:
        print("skip")
        
        print(f"processing_city {city}")
# Out:
# skip
# processing_city illoqqortoormiut
# skip
# processing_city barentsburg
# skip
# processing_city sentyabrskiy
# skip
# processing_city taolanaro
# skip
# processing_city bolungarvik
# skip
# processing_city mocambique
# skip
# processing_city vaitupu
# skip
# processing_city kazalinsk
# skip
# processing_city belushya guba
# skip
# processing_city marcona
# skip
# processing_city tumannyy
# skip
# processing_city bengkulu
# skip
# processing_city samusu
# skip
# processing_city nizhneyansk
# skip
# processing_city amderma
# skip
# processing_city akyab
# skip
# processing_city mys shmidta
# skip
# processing_city stornoway
# skip
# processing_city rudbar
# skip
# processing_city warqla
# skip
# processing_city zolotinka
# skip
# processing_city krasnoselkup
# skip
# processing_city rungata
# skip
# processing_city sulurpeta
# skip
# processing_city attawapiskat
# skip
# processing_city meyungs
# skip
# processing_city asau
# skip
# processing_city hurghada
# skip
# processing_city berbera
# skip
# processing_city zhitikara
# skip
# processing_city kadykchan
# skip
# processing_city acarau
# skip
# processing_city hendijan
# skip
# processing_city mentok
# skip
# processing_city pazardzik
# skip
# processing_city velikie luki
# skip
# processing_city puerto cortes
# skip
# processing_city shaartuz
# skip
# processing_city phan rang
# skip
# processing_city cozumel
# skip
# processing_city severnyy
# skip
# processing_city vitimskiy
# skip
# processing_city mananara
# skip
# processing_city artyk
# skip
# processing_city sug-aksy
# skip
# processing_city falealupo
# skip
# processing_city ndele
# skip
# processing_city tsihombe
# skip
# processing_city inderborskiy
# skip
# processing_city sakakah
# skip
# processing_city zachagansk
# skip
# processing_city grand river south east
# skip
# processing_city catamarca
# skip
# processing_city andenes
# skip
# processing_city wulanhaote
# skip
# processing_city safwah
# skip
# processing_city hihifo
# skip
# processing_city aflu
# skip
# processing_city banmo
# skip
# processing_city saleaula
# skip
# processing_city huazolotitlan
# skip
# processing_city chokwe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
